# %%
ls
# Out:
# sold.csv  sold_home_analytics.ipynb  sold_lastpage.csv

# %%
import pandas as pd

# %%
df = pd.read_csv('sold_lastpage.csv')

# %%
from matplotlib import pyplot as plt

# %%
# %matplotlib inline

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from scipy import stats
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'address_lon', 'listing_data_building_area_sq_ft',
#        'features_flooring', 'address_unit', 'listing_data_sale_history',
#        'features_floors', 'features_year_built', 'address_state',
#        'address_address_line1', 'listing_data_num_bathrooms',
#        'listing_data_sale_price', 'features_interior_features',
#        'images_img_gallery', 'features_is_foreclosure', 'features_lot_size',
#        'features_remax_url', 'address_lat', 'features_num_half_bath',
#        'features_house_size', 'listing_data_home_type', 'features_has_septic',
#        'listing_data_num_bedrooms', 'features_has_pool',
#        'features_listing_status', 'address_slug', 'images_image_header',
#        'features_num_full_bath', 'features_subdivision',
#        'features_has_established_subdivision', 'features_has_well',
#        'features_has_garage', 'features_no_pool_well_septic', 'address_city',
#        'features_garage_detail', 'address_zipcode', 'features_desc'],
#       dtype='object')

# %%
plt.scatter(df['listing_data_building_area_sq_ft'],df['listing_data_sale_price'])

# %%
ax = plt.axes()
sns.distplot(df['listing_data_sale_price'],ax=ax)
ax.set_title('sale price density')
# Out:
# Text(0.5,1,'sale price density')

# %%
x = df['address_lat']

# %%
y = df['address_lon']

# %%
var = 'listing_data_num_bathrooms'
data = pd.concat([df['listing_data_sale_price'],df[var]],axis=1)
f, ax = plt.subplots(figsize=(8,6))
fig = sns.boxplot(x=var,y='listing_data_sale_price',data=data)
ax.set_title('charlotte: price distribution per num bathrooms')
# Out:
# Text(0.5,1,'charlotte: price distribution per num bathrooms')

# %%
df_f = df[df['listing_data_num_bedrooms']<10]
var = 'listing_data_num_bedrooms'
data = pd.concat([df_f['listing_data_sale_price'],df_f[var]],axis=1)
f, ax = plt.subplots(figsize=(8,6))
fig = sns.boxplot(x=var,y='listing_data_sale_price',data=data)
ax.set_title('charlotte: price distribution per num bedrooms')
# Out:
# Text(0.5,1,'charlotte: price distribution per num bedrooms')

# %%
var = 'features_year_built'
data = pd.concat([df['listing_data_sale_price'], df[var]], axis=1)
f, ax = plt.subplots(figsize=(16, 8))
fig = sns.boxplot(x=var, y="listing_data_sale_price", data=data)
fig.axis(ymin=0, ymax=2000000)
plt.xticks(rotation=90)
ax.set_title('price sold vs year built')
# Out:
# Text(0.5,1,'price sold vs year built')

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
g = sns.FacetGrid(df, hue = 'listing_data_sale_price', palette = 'seismic')
g = g.map(plt.scatter, 'address_lon', 'address_lat', s = 25, alpha = 0.5)
g.add_legend()

# %%
plt.scatter(df['address_lon'],df['address_lat'])

# %%
#correlation matrix
df_corr = df.drop(['features_is_foreclosure'],axis=1)
corrmat = df_corr.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=.8, square=True);
ax.set_title('correlation heat map')
# Out:
# Text(0.5,1,'correlation heat map')

# %%
import numpy as np

# %%
cd ../
# Out:
# /home/sanjeev/models/ribbonsemble/ribbonsemble

# %%
cd scripts/csv_data/
# Out:
# /home/sanjeev/models/ribbonsemble/ribbonsemble/scripts/csv_data

# %%
ls
# Out:
# data_20180129.csv  soldhomedata_20180131.csv

# %%
df = pd.read_csv('soldhomedata_20180131.csv')

# %%
a=df['listing_data_sale_history'][0]

# %%
cd ../
# Out:
# /home/sanjeev/models/ribbonsemble/ribbonsemble/scripts

# %%
import load_soldproperties as ls

# %%
ls.url_string_to_json(a)
# Out:
# '["08/30/2017", "159000", "04/29/1998", "17500"]'

# %%
def list2dict(salelist):
    d={}
    try:
        salelist = salelist.split(';')
    except:
        return d 
    iseven = len(salelist) % 2 == 0
    if iseven:
        for idx,data in enumerate(salelist):
            print(idx)
            print(data)
            if idx%2 == 0:
                datakey = data
                d[data] = 0
            if idx%2 == 1:
                d[datakey] = data
        return d
    else:
        return d

# %%
list2dict(a)
# Out:
# 0
# 08/30/2017
# 1
# 159000
# 2
# 04/29/1998
# 3
# 17500
# {'04/29/1998': '17500', '08/30/2017': '159000'}

# %%
len(a.split(';'))%2
# Out:
# 0

# %%
iseven = len(a.split(';')) % 2 == 0

# %%
iseven
# Out:
# True

# %%
b=None

# %%
list2dict(b)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-70-926d0d09ad70> in <module>()
# ----> 1 list2dict(b)
#
# <ipython-input-66-4b07d6b363a5> in list2dict(salelist)
#       1 def list2dict(salelist):
#       2
# ----> 3     salelist = salelist.split(';')
#       4     d={}
#       5     iseven = len(salelist) % 2 == 0
#
# AttributeError: 'NoneType' object has no attribute 'split'
