# %%
ls
# Out:
# sold.csv  sold_home_analytics.ipynb  sold_lastpage.csv

# %%
import pandas as pd

# %%
ls
# Out:
# sold.csv  sold_home_analytics.ipynb  sold_lastpage.csv

# %%
df = pd.read_csv('sold_lastpage.csv')

# %%
from matplotlib import pyplot as plt

# %%
# %matplotlib inline

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from scipy import stats
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'address_lon', 'listing_data_building_area_sq_ft',
#        'features_flooring', 'address_unit', 'listing_data_sale_history',
#        'features_floors', 'features_year_built', 'address_state',
#        'address_address_line1', 'listing_data_num_bathrooms',
#        'listing_data_sale_price', 'features_interior_features',
#        'images_img_gallery', 'features_is_foreclosure', 'features_lot_size',
#        'features_remax_url', 'address_lat', 'features_num_half_bath',
#        'features_house_size', 'listing_data_home_type', 'features_has_septic',
#        'listing_data_num_bedrooms', 'features_has_pool',
#        'features_listing_status', 'address_slug', 'images_image_header',
#        'features_num_full_bath', 'features_subdivision',
#        'features_has_established_subdivision', 'features_has_well',
#        'features_has_garage', 'features_no_pool_well_septic', 'address_city',
#        'features_garage_detail', 'address_zipcode', 'features_desc'],
# ...

# %%
plt.scatter(df['listing_data_building_area_sq_ft'],df['listing_data_sale_price'])

# %%
sns.distplot(df['listing_data_sale_price'])

# %%
x = df['address_lat']

# %%
y = df['address_lon']

# %%
plt.scatter(x,y)

# %%
g = sns.lmplot(x='address_lat',y='address_lon',data=df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/envs/rooftop/lib/python3.6/site-packages/pandas/core/nanops.py in _ensure_numeric(x)
#     795         try:
# --> 796             x = float(x)
#     797         except Exception:
#
# ...

# %%
df['address_lat'].apply(lambda x: float(x))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-9140fca8b0c9> in <module>()
# ----> 1 df['address_lat'].apply(lambda x: float(x))
#
# ~/anaconda3/envs/rooftop/lib/python3.6/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    2549             else:
#    2550                 values = self.asobject
# -> 2551                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    2552
#    2553         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src/inference.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-47-9140fca8b0c9> in <lambda>(x)
# ----> 1 df['address_lat'].apply(lambda x: float(x))
#
# ValueError: could not convert string to float: 'None'

# %%
df = df[pd.notna(df[['address_lat','address_lon']])]

# %%
# Out:
# 2184

# %%
ls
# Out:
# sold.csv  sold_home_analytics.ipynb  sold_lastpage.csv

# %%
cd '../../..'
# Out:
# /home/sanjeev/models

# %%
cd ../image_test/data
# Out:
# /home/sanjeev/image_test/data

# %%
ls
# Out:
# img/  just_header_imgs/

# %%
mypath ='/home/sanjeev/image_test/data/img/'
from os import listdir
from os.path import isfile, join
onlyfiles = [f for f in listdir(mypath) if isfile(join(mypath, f))]

# %%
import glob

# %%
img_list = glob.glob("/home/sanjeev/image_test/data/img/*/*.jpg")

# %%
headers = [x for x in img_list if 'img1.jpg' in x]

# %%
import subprocess

# %%
subprocess.call('cp','-r',headers[0],'/just_header_imgs/test.jpg',shell=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-75-09ed8824553d> in <module>()
# ----> 1 subprocess.call('cp','-r',headers[0],'/just_header_imgs/test.jpg',shell=False)
#
# ~/anaconda3/envs/rooftop/lib/python3.6/subprocess.py in call(timeout, *popenargs, **kwargs)
#     265     retcode = call(["ls", "-l"])
#     266     """
# --> 267     with Popen(*popenargs, **kwargs) as p:
#     268         try:
#     269             return p.wait(timeout=timeout)
#
# ~/anaconda3/envs/rooftop/lib/python3.6/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors)
#     605             bufsize = -1  # Restore default
#     606         if not isinstance(bufsize, int):
# ...

# %%
headers[0]
# Out:
# '/home/sanjeev/image_test/data/img/3308-Brownes-Creek-Rd-Charlotte-NC-28269/img1.jpg'

# %%
ls
# Out:
# img/  just_header_imgs/
